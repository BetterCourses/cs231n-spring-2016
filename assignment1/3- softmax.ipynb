# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
from cs231n.classifiers.softmax import *
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(10, 3073) * 0.0001

# %%
loss, grad = softmax_loss_vectorized(W, X_dev, y_dev, 0.0)

print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.386948
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.647365 analytic: -0.647365, relative error: 3.330718e-08
# numerical: 2.112255 analytic: 2.112255, relative error: 1.856390e-08
# numerical: -0.679959 analytic: -0.679959, relative error: 1.827719e-08
# numerical: -2.420397 analytic: -2.420397, relative error: 9.781495e-09
# numerical: 3.063365 analytic: 3.063365, relative error: 1.700048e-09
# numerical: 0.169066 analytic: 0.169066, relative error: 3.105295e-09
# numerical: 1.287382 analytic: 1.287382, relative error: 1.117087e-08
# numerical: -1.943063 analytic: -1.943063, relative error: 3.032383e-08
# numerical: -0.650810 analytic: -0.650810, relative error: 1.034027e-08
# numerical: -1.160447 analytic: -1.160447, relative error: 4.728946e-08
# numerical: -1.213231 analytic: -1.213231, relative error: 1.172189e-08
# numerical: -2.171303 analytic: -2.171303, relative error: 1.808224e-08
# numerical: 1.844097 analytic: 1.844097, relative error: 6.670005e-08
# numerical: -0.810025 analytic: -0.810025, relative error: 7.786613e-10
# numerical: 0.713691 analytic: 0.713691, relative error: 4.123474e-08
# numerical: 0.165523 analytic: 0.165523, relative error: 7.588371e-08
# numerical: -4.681060 analytic: -4.681060, relative error: 7.665857e-09
# numerical: 2.707416 analytic: 2.707416, relative error: 3.015242e-08
# numerical: -1.330957 analytic: -1.330957, relative error: 1.842010e-08
# numerical: 1.141129 analytic: 1.141129, relative error: 1.776206e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.386948e+00 computed in 0.059625s
# vectorized loss: 2.386948e+00 computed in 0.005468s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-7, 3e-7, 5e-5, 8e-7]
regularization_strengths = [1e4, 2e4, 3e4, 4e4, 5e4, 6e4, 7e4, 8e4, 1e5]

for lr in learning_rates:
    for rs in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=rs,
                                  num_iters=1500, verbose=False)
        
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        
        train_accuracy = np.mean(y_train_pred == y_train)
        val_accuracy = np.mean(y_val_pred == y_val)
        
        results[(lr, rs)] = (train_accuracy, val_accuracy)
        
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax
    
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# cs231n/classifiers/softmax.py:95: RuntimeWarning: divide by zero encountered in log
#   loss = np.mean(-np.log(p_yi))
# cs231n/classifiers/softmax.py:96: RuntimeWarning: overflow encountered in double_scalars
#   loss += 0.5 * reg * np.sum(W * W)  # regularization
# cs231n/classifiers/softmax.py:96: RuntimeWarning: overflow encountered in multiply
#   loss += 0.5 * reg * np.sum(W * W)  # regularization
# cs231n/classifiers/softmax.py:84: RuntimeWarning: overflow encountered in subtract
#   scores -= np.amax(scores, axis=1).reshape(N, 1)
# cs231n/classifiers/softmax.py:84: RuntimeWarning: invalid value encountered in subtract
#   scores -= np.amax(scores, axis=1).reshape(N, 1)
# cs231n/classifiers/softmax.py:105: RuntimeWarning: overflow encountered in multiply
#   dW += reg * W
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.333612 val accuracy: 0.339000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.353633 val accuracy: 0.363000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.345327 val accuracy: 0.362000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.337776 val accuracy: 0.346000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.329347 val accuracy: 0.344000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.326245 val accuracy: 0.344000
# lr 1.000000e-07 reg 7.000000e+04 train accuracy: 0.316469 val accuracy: 0.335000
# lr 1.000000e-07 reg 8.000000e+04 train accuracy: 0.317980 val accuracy: 0.332000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.304367 val accuracy: 0.321000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.367041 val accuracy: 0.392000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.359755 val accuracy: 0.375000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.346551 val accuracy: 0.361000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.337000 val accuracy: 0.352000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.328673 val accuracy: 0.341000
# lr 2.000000e-07 reg 6.000000e+04 train accuracy: 0.328633 val accuracy: 0.340000
# lr 2.000000e-07 reg 7.000000e+04 train accuracy: 0.312551 val accuracy: 0.325000
# lr 2.000000e-07 reg 8.000000e+04 train accuracy: 0.310878 val accuracy: 0.333000
# lr 2.000000e-07 reg 1.000000e+05 train accuracy: 0.304796 val accuracy: 0.321000
# lr 3.000000e-07 reg 1.000000e+04 train accuracy: 0.370694 val accuracy: 0.381000
# lr 3.000000e-07 reg 2.000000e+04 train accuracy: 0.354367 val accuracy: 0.369000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.346898 val accuracy: 0.359000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.331980 val accuracy: 0.345000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.328694 val accuracy: 0.337000
# lr 3.000000e-07 reg 6.000000e+04 train accuracy: 0.328082 val accuracy: 0.338000
# lr 3.000000e-07 reg 7.000000e+04 train accuracy: 0.318367 val accuracy: 0.329000
# lr 3.000000e-07 reg 8.000000e+04 train accuracy: 0.308857 val accuracy: 0.323000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.299204 val accuracy: 0.326000
# lr 8.000000e-07 reg 1.000000e+04 train accuracy: 0.369755 val accuracy: 0.378000
# lr 8.000000e-07 reg 2.000000e+04 train accuracy: 0.351469 val accuracy: 0.360000
# lr 8.000000e-07 reg 3.000000e+04 train accuracy: 0.332184 val accuracy: 0.353000
# lr 8.000000e-07 reg 4.000000e+04 train accuracy: 0.320653 val accuracy: 0.329000
# lr 8.000000e-07 reg 5.000000e+04 train accuracy: 0.323204 val accuracy: 0.331000
# lr 8.000000e-07 reg 6.000000e+04 train accuracy: 0.317469 val accuracy: 0.334000
# lr 8.000000e-07 reg 7.000000e+04 train accuracy: 0.301571 val accuracy: 0.322000
# lr 8.000000e-07 reg 8.000000e+04 train accuracy: 0.318633 val accuracy: 0.329000
# lr 8.000000e-07 reg 1.000000e+05 train accuracy: 0.293184 val accuracy: 0.308000
# lr 5.000000e-05 reg 1.000000e+04 train accuracy: 0.133735 val accuracy: 0.142000
# lr 5.000000e-05 reg 2.000000e+04 train accuracy: 0.087429 val accuracy: 0.088000
# lr 5.000000e-05 reg 3.000000e+04 train accuracy: 0.062735 val accuracy: 0.049000
# lr 5.000000e-05 reg 4.000000e+04 train accuracy: 0.132041 val accuracy: 0.141000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.064041 val accuracy: 0.071000
# lr 5.000000e-05 reg 6.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 8.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.392000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.374000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:,:-1] # strip out the bias
w = w.reshape(10, 32, 32, 3)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[i, :, :, :].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
